# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/CHARU/Pictures/ML/Simplilearn/AppliedDataScienceWithPython/ProjectPractice/Customer_Service_Requests_Analysis_Dataset/311_Service_Requests_from_2010_to_Present.csv")
# Out:
# C:\Users\CHARU\AppData\Local\Temp\ipykernel_12460\463579085.py:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:/Users/CHARU/Pictures/ML/Simplilearn/AppliedDataScienceWithPython/ProjectPractice/Customer_Service_Requests_Analysis_Dataset/311_Service_Requests_from_2010_to_Present.csv")

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
df.shape
# Out:
# (364558, 53)

# %%
df.isnull().sum().plot(kind="bar", figsize=(12,7), title="Missing Values", ylabel="Frequency")
# Out:
# <AxesSubplot:title={'center':'Missing Values'}, ylabel='Frequency'>

# %%
df.dropna(subset=["Closed Date"], inplace=True)

# %%
df.shape
# Out:
# (362177, 53)

# %%
df.isnull().sum()["Closed Date"]
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362177 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      362177 non-null  int64
#  1   Created Date                    362177 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          362177 non-null  object
#  4   Agency Name                     362177 non-null  object
#  5   Complaint Type                  362177 non-null  object
#  6   Descriptor                      355681 non-null  object
#  7   Location Type                   362047 non-null  object
#  8   Incident Zip                    361502 non-null  float64
#  9   Incident Address                310491 non-null  object
#  10  Street Name                     310491 non-null  object
#  11  Cross Street 1                  306846 non-null  object
# ...

# %%
df1 = df[['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
       'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
       'City', 'Status', 'Due Date',
       'Resolution Description','Borough', 'Latitude', 'Longitude', 'Location']]

# %%
df1.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip      City  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0  NEW YORK
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362177 entries, 0 to 364557
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unique Key              362177 non-null  int64
#  1   Created Date            362177 non-null  object
#  2   Closed Date             362177 non-null  object
#  3   Agency                  362177 non-null  object
#  4   Agency Name             362177 non-null  object
#  5   Complaint Type          362177 non-null  object
#  6   Descriptor              355681 non-null  object
#  7   Location Type           362047 non-null  object
#  8   Incident Zip            361502 non-null  float64
#  9   City                    361503 non-null  object
#  10  Status                  362177 non-null  object
#  11  Due Date                362176 non-null  object
#  12  Resolution Description  362177 non-null  object
#  13  Borough                 362177 non-null  object
# ...

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])

# %%
df['Closed Date'] = pd.to_datetime(df['Closed Date'])

# %%
df['Elapsed Time'] = df['Closed Date'] - df['Created Date']

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
df =  df[['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
       'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
       'City', 'Status', 'Due Date',
       'Resolution Description','Borough', 'Latitude', 'Longitude', 'Location']]

# %%
df['Elapsed Time'] = df['Closed Date'] - df['Created Date']
# Out:
# C:\Users\CHARU\AppData\Local\Temp\ipykernel_12460\363491618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Elapsed Time'] = df['Closed Date'] - df['Created Date']

# %%
df.loc[0:10, ["Unique Key", "Created Date", "Closed Date"]]
# Out:
#     Unique Key        Created Date         Closed Date    Elapsed Time
# 0     32310363 2015-12-31 23:59:45 2016-01-01 00:55:15 0 days 00:55:30
# 1     32309934 2015-12-31 23:59:44 2016-01-01 01:26:57 0 days 01:27:13
# 2     32309159 2015-12-31 23:59:29 2016-01-01 04:51:03 0 days 04:51:34
# 3     32305098 2015-12-31 23:57:46 2016-01-01 07:43:13 0 days 07:45:27
# 4     32306529 2015-12-31 23:56:58 2016-01-01 03:24:42 0 days 03:27:44
# 5     32306554 2015-12-31 23:56:30 2016-01-01 01:50:11 0 days 01:53:41
# 6     32306559 2015-12-31 23:55:32 2016-01-01 01:53:54 0 days 01:58:22
# 7     32307009 2015-12-31 23:54:05 2016-01-01 01:42:54 0 days 01:48:49
# 8     32308581 2015-12-31 23:53:58 2016-01-01 08:27:32 0 days 08:33:34
# 9     32308391 2015-12-31 23:53:58 2016-01-01 01:17:40 0 days 01:23:42
# 10    32305071 2015-12-31 23:52:58 2016-01-01 07:41:38 0 days 07:48:40

# %%
df['Elapsed Time'].dt.total_seconds().astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12460\4259621034.py in <module>
# ----> 1 df['Elapsed Time'].dt.total_seconds().astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df.loc[0:10, ["Unique Key", "Created Date", "Closed Date", "Elapsed Time"]]
# Out:
#     Unique Key        Created Date         Closed Date    Elapsed Time
# 0     32310363 2015-12-31 23:59:45 2016-01-01 00:55:15 0 days 00:55:30
# 1     32309934 2015-12-31 23:59:44 2016-01-01 01:26:57 0 days 01:27:13
# 2     32309159 2015-12-31 23:59:29 2016-01-01 04:51:03 0 days 04:51:34
# 3     32305098 2015-12-31 23:57:46 2016-01-01 07:43:13 0 days 07:45:27
# 4     32306529 2015-12-31 23:56:58 2016-01-01 03:24:42 0 days 03:27:44
# 5     32306554 2015-12-31 23:56:30 2016-01-01 01:50:11 0 days 01:53:41
# 6     32306559 2015-12-31 23:55:32 2016-01-01 01:53:54 0 days 01:58:22
# 7     32307009 2015-12-31 23:54:05 2016-01-01 01:42:54 0 days 01:48:49
# 8     32308581 2015-12-31 23:53:58 2016-01-01 08:27:32 0 days 08:33:34
# 9     32308391 2015-12-31 23:53:58 2016-01-01 01:17:40 0 days 01:23:42
# 10    32305071 2015-12-31 23:52:58 2016-01-01 07:41:38 0 days 07:48:40

# %%
df.shape
# Out:
# (362177, 18)

# %%
df.info["Elapsed Time"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12460\3573299686.py in <module>
# ----> 1 df.info["Elapsed Time"]
#
# TypeError: 'method' object is not subscriptable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362177 entries, 0 to 364557
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unique Key              362177 non-null  int64
#  1   Created Date            362177 non-null  datetime64[ns]
#  2   Closed Date             362177 non-null  datetime64[ns]
#  3   Agency                  362177 non-null  object
#  4   Agency Name             362177 non-null  object
#  5   Complaint Type          362177 non-null  object
#  6   Descriptor              355681 non-null  object
#  7   Location Type           362047 non-null  object
#  8   Incident Zip            361502 non-null  float64
#  9   City                    361503 non-null  object
#  10  Status                  362177 non-null  object
#  11  Due Date                362176 non-null  object
#  12  Resolution Description  362177 non-null  object
# ...

# %%
df.isnull().sum()["City", "Complaint Type"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12460\2158698108.py in <module>
# ----> 1 df.isnull().sum()["City", "Complaint Type"]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     997             )
#     998         elif isinstance(key, tuple):
# --> 999             return self._get_values_tuple(key)
#    1000
#    1001         elif not is_list_like(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#    1032
#    1033         if not isinstance(self.index, MultiIndex):
# ...

# %%
df.isnull().sum()[["City", "Complaint Type"]]
# Out:
# City              674
# Complaint Type      0
# dtype: int64

# %%
df["City"].fillna(value="Unknown City",inplace=True)
# Out:
# C:\Users\CHARU\AppData\Local\Temp\ipykernel_12460\3619825473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"].fillna(value="Unknown City",inplace=True)

# %%
df.isnull().sum()[["City", "Complaint Type"]]
# Out:
# City              0
# Complaint Type    0
# dtype: int64

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip      City  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0  NEW YORK
# 1                     No Access  Street/Sidewalk       11105.0   ASTORIA
# ...

# %%
df[["City"]=="Unkown City"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[df['City'] == "Unknown City"]
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 33        32306700 2015-12-31 23:18:10 2016-01-02 01:04:03   NYPD
# 283       32309451 2015-12-31 17:40:16 2016-01-01 10:59:11   NYPD
# 302       32309860 2015-12-31 17:05:30 2016-01-01 08:17:35   NYPD
# 1421      32299438 2015-12-30 11:55:25 2015-12-30 14:35:54   NYPD
# 2131      32294310 2015-12-29 14:53:28 2015-12-29 17:46:06   NYPD
# ...            ...                 ...                 ...    ...
# 361851    29633795 2015-01-04 23:19:28 2015-01-05 10:13:06   NYPD
# 361912    29632589 2015-01-04 21:20:56 2015-01-05 13:46:10   NYPD
# 361975    29633040 2015-01-04 20:04:21 2015-01-05 13:07:15   NYPD
# 362048    29633311 2015-01-04 18:21:17 2015-01-06 08:26:39   NYPD
# 364053    29618280 2015-01-01 19:24:31 2015-01-01 23:44:53   NYPD
#
#                             Agency Name      Complaint Type  \
# 33      New York City Police Department     Illegal Parking
# ...

# %%
plt.figure(figsize=(20,18))

# %%
sns.countplot(data=df, y='City')
# Out:
# <AxesSubplot:xlabel='count', ylabel='City'>

# %%
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.countplot(data=df, y='City')
plt.title("Citywise Total Complaints")
plt.show()

# %%
df_Brooklyn = df[df['Borough'] == 'BROOKLYN']

# %%
df_Brooklyn.head()
# Out:
#     Unique Key        Created Date         Closed Date Agency  \
# 5     32306554 2015-12-31 23:56:30 2016-01-01 01:50:11   NYPD
# 9     32308391 2015-12-31 23:53:58 2016-01-01 01:17:40   NYPD
# 13    32305074 2015-12-31 23:47:58 2016-01-01 08:18:47   NYPD
# 17    32310273 2015-12-31 23:44:52 2016-01-01 00:36:10   NYPD
# 18    32306617 2015-12-31 23:40:59 2016-01-01 02:37:28   NYPD
#
#                         Agency Name      Complaint Type  \
# 5   New York City Police Department     Illegal Parking
# 9   New York City Police Department    Blocked Driveway
# 13  New York City Police Department     Illegal Parking
# 17  New York City Police Department  Noise - Commercial
# 18  New York City Police Department  Noise - Commercial
#
#                        Descriptor        Location Type  Incident Zip  \
# 5   Posted Parking Sign Violation      Street/Sidewalk       11215.0
# 9                       No Access      Street/Sidewalk       11219.0
# ...

# %%
df_Brooklyn[['Latitude', 'Longitude']].plot(kind='scatter', x='Longitude', y='Latitude', title='Complaints concentration across Brooklyn', figsize=(10,8))
# Out:
# <AxesSubplot:title={'center':'Complaints concentration across Brooklyn'}, xlabel='Longitude', ylabel='Latitude'>

# %%
df_newYork = df[df['City'] == 'NEW YORK']

# %%
df_newYork
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 6         32306559 2015-12-31 23:55:32 2016-01-01 01:53:54   NYPD
# 19        32308195 2015-12-31 23:40:55 2016-01-01 00:28:31   NYPD
# 23        32308765 2015-12-31 23:32:46 2016-01-01 00:25:21   NYPD
# 26        32305916 2015-12-31 23:26:41 2015-12-31 23:53:31   NYPD
# ...            ...                 ...                 ...    ...
# 364542    29607990 2015-01-01 00:19:20 2015-01-01 03:17:10   NYPD
# 364543    29609631 2015-01-01 00:18:49 2015-01-01 03:17:11   NYPD
# 364547    29608295 2015-01-01 00:15:33 2015-01-01 00:56:37   NYPD
# 364552    29610051 2015-01-01 00:05:05 2015-01-01 01:22:10   NYPD
# 364555    29607589 2015-01-01 00:01:30 2015-01-01 00:20:33   NYPD
#
#                             Agency Name            Complaint Type  \
# 0       New York City Police Department   Noise - Street/Sidewalk
# ...

# %%
df_newYork['Complaint Type'].value_counts().sort_values(ascending=False)
# Out:
# Noise - Street/Sidewalk      22245
# Noise - Commercial           18686
# Illegal Parking              14549
# Noise - Vehicle               6294
# Homeless Encampment           3060
# Blocked Driveway              2705
# Vending                       2638
# Animal Abuse                  1941
# Traffic                       1769
# Noise - Park                  1243
# Derelict Vehicle               695
# Drinking                       321
# Urinating in Public            264
# Bike/Roller/Skate Chronic      254
# Noise - House of Worship       222
# Panhandling                    206
# Disorderly Youth                81
# Posting Advertisement           49
# Illegal Fireworks               38
# Graffiti                        25
# Squeegee                         4
# Name: Complaint Type, dtype: int64

# %%
df.groupby(['City','Complaint Type']).size()
# Out:
# City      Complaint Type
# ARVERNE   Animal Abuse                46
#           Blocked Driveway            50
#           Derelict Vehicle            32
#           Disorderly Youth             2
#           Drinking                     1
#                                     ...
# Woodside  Blocked Driveway            27
#           Derelict Vehicle             8
#           Illegal Parking            124
#           Noise - Commercial           2
#           Noise - Street/Sidewalk      5
# Length: 792, dtype: int64

# %%
pd.crosstab(df['City'],df['Complaint Type'])
# Out:
# Complaint Type       Agency Issues  Animal Abuse  Animal in a Park  \
# City
# ARVERNE                          0            46                 0
# ASTORIA                          0           170                 0
# Astoria                          0             0                 0
# BAYSIDE                          0            53                 0
# BELLEROSE                        0            15                 0
# BREEZY POINT                     0             2                 0
# BRONX                            0          1971                 0
# BROOKLYN                         0          3191                 0
# CAMBRIA HEIGHTS                  0            15                 0
# CENTRAL PARK                     0             0                 0
# COLLEGE POINT                    0            35                 0
# CORONA                           0           104                 0
# EAST ELMHURST                    0            85                 0
# ...

# %%
df_new  = df.groupby(['City','Complaint Type']).size().unstack()

# %%
df_new.plot(kind="barh", stacked=True, figsize=(20,18))
plt.show()

# %%
# we can also visualise for top 5 cities which is easier and clearer to visualize
top5city=df['City'].value_counts().head(5)

# %%
df_new.head()
# Out:
# Complaint Type  Agency Issues  Animal Abuse  Animal in a Park  \
# City
# ARVERNE                   NaN          46.0               NaN
# ASTORIA                   NaN         170.0               NaN
# Astoria                   NaN           NaN               NaN
# BAYSIDE                   NaN          53.0               NaN
# BELLEROSE                 NaN          15.0               NaN
#
# Complaint Type  Bike/Roller/Skate Chronic  Blocked Driveway  Derelict Vehicle  \
# City
# ARVERNE                               NaN              50.0              32.0
# ASTORIA                              16.0            3436.0             426.0
# Astoria                               NaN             159.0              14.0
# BAYSIDE                               NaN             514.0             231.0
# BELLEROSE                             1.0             138.0             120.0
#
# Complaint Type  Disorderly Youth  Drinking  Graffiti  Homeless Encampment  \
# City
# ...

# %%
df.describe()
# Out:
#          Unique Key   Incident Zip       Latitude      Longitude  Elapsed Time
# count  3.621770e+05  361502.000000  360470.000000  360470.000000  3.621770e+05
# mean   3.106545e+07   10858.533377      40.724978     -73.924942  1.511330e+04
# std    7.337572e+05     578.254027       0.081908       0.079212  2.110255e+04
# min    2.960737e+07      83.000000      40.499040     -74.254937  6.100000e+01
# 25%    3.049763e+07   10314.000000      40.668741     -73.972248  4.533000e+03
# 50%    3.108661e+07   11209.000000      40.718398     -73.930630  9.616000e+03
# 75%    3.167497e+07   11238.000000      40.778160     -73.874098  1.887800e+04
# max    3.231065e+07   11697.000000      40.912869     -73.700715  2.134342e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362177 entries, 0 to 364557
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unique Key              362177 non-null  int64
#  1   Created Date            362177 non-null  datetime64[ns]
#  2   Closed Date             362177 non-null  datetime64[ns]
#  3   Agency                  362177 non-null  object
#  4   Agency Name             362177 non-null  object
#  5   Complaint Type          362177 non-null  object
#  6   Descriptor              355681 non-null  object
#  7   Location Type           362047 non-null  object
#  8   Incident Zip            361502 non-null  float64
#  9   City                    362177 non-null  object
#  10  Status                  362177 non-null  object
#  11  Due Date                362176 non-null  object
#  12  Resolution Description  362177 non-null  object
# ...

# %%
df['Resolution Time'] = (df['Closed Date'] - df['Created Date']).dt.minute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12460\1801612192.py in <module>
# ----> 1 df['Resolution Time'] = (df['Closed Date'] - df['Created Date']).dt.minute
#
# AttributeError: 'TimedeltaProperties' object has no attribute 'minute'

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip      City  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0  NEW YORK
# 1                     No Access  Street/Sidewalk       11105.0   ASTORIA
# ...

# %%
df['Resolution Time'].value_counts()
# Out:
# 0     358248
# 1       3247
# 2        463
# 3        130
# 5         34
# 4         30
# 6         14
# 8          3
# 24         3
# 9          2
# 21         1
# 7          1
# 14         1
# Name: Resolution Time, dtype: int64

# %%
df.groupby(['City','Complaint Type','Resolution Time'])[['City','Complaint Type','Resolution Time']].sum()
# Out:
#                                                   Resolution Time
# City     Complaint Type          Resolution Time
# ARVERNE  Animal Abuse            0                              0
#          Blocked Driveway        0                              0
#          Derelict Vehicle        0                              0
#          Disorderly Youth        0                              0
#          Drinking                0                              0
# ...                                                           ...
# Woodside Derelict Vehicle        0                              0
#          Illegal Parking         0                              0
#                                  1                              1
#          Noise - Commercial      0                              0
#          Noise - Street/Sidewalk 0                              0
#
# [1212 rows x 1 columns]

# %%
df.tail()
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 364553    29609918 2015-01-01 00:04:44 2015-01-01 10:22:31   NYPD
# 364554    29608392 2015-01-01 00:04:28 2015-01-01 02:25:02   NYPD
# 364555    29607589 2015-01-01 00:01:30 2015-01-01 00:20:33   NYPD
# 364556    29610889 2015-01-01 00:01:29 2015-01-01 02:42:22   NYPD
# 364557    29611816 2015-01-01 00:00:50 2015-01-01 02:47:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 364553  New York City Police Department          Illegal Parking
# 364554  New York City Police Department          Noise - Vehicle
# 364555  New York City Police Department  Noise - Street/Sidewalk
# 364556  New York City Police Department         Blocked Driveway
# 364557  New York City Police Department         Blocked Driveway
#
#               Descriptor    Location Type  Incident Zip              City  \
# 364553   Blocked Hydrant  Street/Sidewalk       11421.0         WOODHAVEN
# ...

# %%
df[df['Resolution Time'] == 5]
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 7454      32260148 2015-12-23 10:27:53 2015-12-28 16:28:50   NYPD
# 26563     32129394 2015-12-05 01:35:55 2015-12-10 02:12:08   NYPD
# 26647     32130222 2015-12-05 00:34:31 2015-12-10 02:12:05   NYPD
# 27360     32132140 2015-12-04 11:33:13 2015-12-10 02:09:45   NYPD
# 27629     32133544 2015-12-04 04:32:09 2015-12-10 01:48:20   NYPD
# 39547     32041074 2015-11-21 12:14:18 2015-11-27 10:27:20   NYPD
# 43732     32010828 2015-11-17 15:34:11 2015-11-22 16:56:10   NYPD
# 51811     31941850 2015-11-09 15:12:39 2015-11-14 16:38:43   NYPD
# 79165     31756095 2015-10-15 08:28:19 2015-10-20 16:18:02   NYPD
# 79779     31751372 2015-10-14 19:08:05 2015-10-20 16:18:01   NYPD
# 241144    30704603 2015-05-26 15:28:09 2015-05-31 15:35:15   NYPD
# 241152    30701316 2015-05-26 15:13:08 2015-05-31 15:35:14   NYPD
# 241157    30700285 2015-05-26 15:09:15 2015-05-31 15:33:03   NYPD
# ...

# %%
df['Request_Closing_Time']= df['Closed Date'].values-df['Created Date'].values
# Out:
# C:\Users\CHARU\AppData\Local\Temp\ipykernel_12460\1174939045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request_Closing_Time']= df['Closed Date'].values-df['Created Date'].values

# %%
df['Request_Closing_Time_mins'] = df['Request_Closing_Time']/np.timedelta64(1,'m')
# Out:
# C:\Users\CHARU\AppData\Local\Temp\ipykernel_12460\940330575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request_Closing_Time_mins'] = df['Request_Closing_Time']/np.timedelta64(1,'m')

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip      City  ...  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0  NEW YORK  ...
# ...

# %%
df9 = df.groupby(['City','Complaint Type'])['Request_Closing_Time_mins'].mean()
# df9.unstack().fillna(0).head()

# %%
df9.unstack().fillna(0).head()
# Out:
# Complaint Type  Agency Issues  Animal Abuse  Animal in a Park  \
# City
# ARVERNE                   0.0    139.986594               0.0
# ASTORIA                   0.0    286.781373               0.0
# Astoria                   0.0      0.000000               0.0
# BAYSIDE                   0.0    186.725786               0.0
# BELLEROSE                 0.0    532.820000               0.0
#
# Complaint Type  Bike/Roller/Skate Chronic  Blocked Driveway  Derelict Vehicle  \
# City
# ARVERNE                          0.000000        138.647333        189.900000
# ASTORIA                        111.979167        275.265575        540.776643
# Astoria                          0.000000        274.881027        417.207143
# BAYSIDE                          0.000000        155.765759        204.360462
# BELLEROSE                      293.600000        501.905435        920.781389
#
# Complaint Type  Disorderly Youth    Drinking    Graffiti  Homeless Encampment  \
# City
# ...

# %%
plt.figure(figsize=(15,12))
plt.title("Avg Response Time across different complaint types")
df.groupby('Complaint Type')['Request_Closing_Time_mins'].mean().plot(kind="barh")
# Out:
# <AxesSubplot:title={'center':'Avg Response Time across different complaint types'}, ylabel='Complaint Type'>

# %%
top5city=df['City'].value_counts().head(5).index.to_list()

# %%
top5city
# Out:
# ['BROOKLYN', 'NEW YORK', 'BRONX', 'STATEN ISLAND', 'JAMAICA']
